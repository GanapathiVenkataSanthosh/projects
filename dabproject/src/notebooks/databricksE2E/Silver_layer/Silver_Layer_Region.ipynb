# %%
df = spark.read.table("databricks_cat.bronze.region")
display(df)

# %%
df = df.drop("_rescued_data")
display(df)

# %%
df.write.mode("overwrite").format("delta").save("abfss://silver@databricksgvse2e.dfs.core.windows.net/region")

# %%
df = spark.read.format("delta").load("abfss://silver@databricksgvse2e.dfs.core.windows.net/region")
display(df)

# %%
# %sql
CREATE TABLE IF NOT EXISTS databricks_cat.silver.region
USING DELTA
LOCATION 'abfss://silver@databricksgvse2e.dfs.core.windows.net/region'
